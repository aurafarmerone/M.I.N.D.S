# %%
import pandas as pd

# %%
data = pd.read_csv("raw_data.csv")

# %%
# cleaning data then export to new file

cdata = data.copy()

cdata = cdata.drop_duplicates()
cdata = cdata.fillna(0)

# export
cdata.to_csv("CleanedData.csv")
