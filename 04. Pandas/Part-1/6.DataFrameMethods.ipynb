# %%
import pandas as pd

# %%
data = pd.read_csv("employee_data.csv")
print(data)
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
# Data Frame methods

# df.head() : display top 5 rows
data.head()
data.head(10) # display first 10 rows


# .tail() : last 5 rows
data.tail()


# .sample() : any random row
data.sample(5) # random 5 rows

# .info() : basic info about data
data.info()

# .describe() : useful data like mean , etc
data.describe()


data.columns # display all columns name
data.shape # (row x cols)
data.nunique() # count all unique entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10 non-null     int64
#  1   Name        10 non-null     object
#  2   Age         10 non-null     int64
#  3   Department  10 non-null     object
#  4   Salary      10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes
# ID            10
# Name          10
# Age           10
# Department     4
# Salary        10
# dtype: int64
