# %%
import pandas as pd

# %%
data = pd.read_csv("CleanedData.csv")

# data.hist() ---> show all label
data["age"].hist() # for specific label
# Out:
# <Axes: >

# %%
# mathod2 using plot

data.plot(kind="scatter" , x="age" , y="income")
# Out:
# <Axes: xlabel='age', ylabel='income'>
