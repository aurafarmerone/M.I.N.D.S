# %%
import pandas as pd

# pandas : data cleaning and manupulation tool
# Series : 1D labelled data
# DataFrame : 2D labelled data

# %%
#  data in form of dict (key-value)
data = {
    "Name" : ["Ritik" , "Rishi" , "Shradha"] ,
    "Branch" : ["ML" , "CSE" , "AI"] ,
    "CGPA" : [9.2 , 9.9 , 9.4]
}

# convert dict data to Pandas DataFrame(Table) data
pData = pd.DataFrame(data)

# output 1
print(pData)

# O/P 2:
pData
# Out:
#       Name Branch  CGPA
# 0    Ritik     ML   9.2
# 1    Rishi    CSE   9.9
# 2  Shradha     AI   9.4
#       Name Branch  CGPA
# 0    Ritik     ML   9.2
# 1    Rishi    CSE   9.9
# 2  Shradha     AI   9.4

# %%
Sdata = pd.Series(data) # series data

sdata
# Out:
# Name      [Ritik, Rishi, Shradha]
# Branch              [ML, CSE, AI]
# dtype: object
