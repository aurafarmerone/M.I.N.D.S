# %%
import pandas as pd

# %%
data = pd.read_csv("engineering_placement.csv")

# selection
data.head(10)
data[["branch","cgpa"]]
# Out:
#      branch   cgpa
# 0       ECE   8.74
# 1       ECE   7.80
# 2        IT   6.95
# 3       ECE   7.46
# 4        IT   6.86
# ...     ...    ...
# 4995     IT  10.00
# 4996     IT   7.76
# 4997     IT   7.79
# 4998    ECE   8.76
# 4999    CSE   9.45
#
# [5000 rows x 2 columns]
